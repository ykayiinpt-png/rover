# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read CSV file
df = pd.read_csv(".\\inputs\\pid_orientation_left_wheel.csv")

# %%
# Show first rows
print(df.head())

# Plot a column
df["Command_y"].plot()
df["Target_y"].plot()

# Add labels
plt.title("Sales Over Time")
plt.xlabel("Index")
plt.ylabel("Sales")

# Show plot
plt.show()
# Out:
#       Command_x   Command_y      Target_x  Target_y
# 0  1.779991e+09  199.968419  1.779991e+09       0.0
# 1  1.779991e+09  199.968419  1.779991e+09       0.0
# 2  1.779991e+09  199.968419  1.779991e+09       0.0
# 3  1.779991e+09  199.968419  1.779991e+09       0.0
# 4  1.779991e+09  199.968419  1.779991e+09       0.0
